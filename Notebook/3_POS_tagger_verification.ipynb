# %% [markdown]
# # spaCy POS tagger: is it good for us?
# In this notebook we will explore a little bit the spaCy's built in POS tagger to see if it is actually good for our context (lyrics). We will read some song lyrics and parse them with spaCy. Let's see what we get.
#
# It is important to say that spaCy's POS tagger provides two tags per words:
#  - `pos`: coarse-grained part-of-speech e.g. VERB
#  - `tag`: fine-grained part-of-speech e.g. PAST_TENSE
#
# We will analyze both tags.

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# We will begin by working on Nirvana's song Polly becase....I like it ([link](https://www.youtube.com/watch?v=atx9X4s6_zg)) .

# %%
path = 'ml_lyrics/sad_Nirvana_Polly'

# %%
with open(path, 'r') as f:
    lyrics = f.read()
    print(lyrics)
# Out:
# Polly wants a cracker
# Think I should get off her first
# Think she wants some water
# To put out the blow torch
#
# Isn't me, have a seed
# Let me clip, dirty wings
# Let me take a ride, cut yourself
# Want some help, please myself
# Got some rope, have been told
# Promise you, have been true
# Let me take a ride, cut yourself
# Want some help, please myself
#
# Polly wants a cracker
# Maybe she would like some food
# She asks me to untie her
# Chase would be nice for a few
#
# Isn't me, have a seed
# Let me clip, dirty wings
# Let me take a ride, cut yourself
# Want some help, please myself
# Got some rope, have been told
# Promise you, have been true
# Let me take a ride, cut yourself
# Want some help, please myself
#
# Polly said
#
# Polly says her back hurts
# She's just as bored as me
# She caught me off my guard
# 'Mazes me the will of instinct
#
# Isn't me, have a seed
# Let me clip, dirty wings
# Let me take a ride, cut yourself
# Want some help, please myself
# Got some rope, have been told
# Promise you, have been true
# Let me take a ride, cut yourself
# Want some help, please myself

# %% [markdown]
# There are some duplicate parts. I will drop them.

# %%
parts = lyrics.split('\n\n')
print('We had {} parts'.format(len(parts)))
parts = list(set(parts))
print('Now we have {} parts'.format(len(parts)))
# Out:
# We had 7 parts
# Now we have 5 parts

# %%
lyrics = '\n\n'.join(parts)
lyrics = nlp(lyrics)
print(lyrics)
# Out:
# Polly wants a cracker
# Think I should get off her first
# Think she wants some water
# To put out the blow torch
#
# Polly said
#
# Polly says her back hurts
# She's just as bored as me
# She caught me off my guard
# 'Mazes me the will of instinct
#
# Isn't me, have a seed
# Let me clip, dirty wings
# Let me take a ride, cut yourself
# Want some help, please myself
# Got some rope, have been told
# Promise you, have been true
# Let me take a ride, cut yourself
# Want some help, please myself
#
# Polly wants a cracker
# Maybe she would like some food
# She asks me to untie her
# Chase would be nice for a few

# %%
def get_lines():
    return lyrics.text.split('\n')

# %%
lines = get_lines()

# %%
def describe_line(line):
    line = nlp(line)
    print(line)
    for token in line:
        print(token.pos_, end=' ')
    print('\n')
    for token in line:
        print(token.text, '=', token.pos_,  token.tag_, '->', spacy.explain(token.tag_))

# %% [markdown]
# Firstly let's have a look at the first line and see what we get.

# %%
# Let's have a look at the first line
describe_line(lines[0])
# Out:
# Polly wants a cracker
# PROPN VERB DET NOUN
#
# Polly = PROPN NNP -> noun, proper singular
# wants = VERB VBZ -> verb, 3rd person singular present
# a = DET DT -> determiner
# cracker = NOUN NN -> noun, singular or mass

# %% [markdown]
# Makes sense! Problems may arise on the whole song lyric. Let's see.

# %%
for line in lines:
    describe_line(line)
    print('-'*30)
# Out:
# Polly wants a cracker
# PROPN VERB DET NOUN
#
# Polly = PROPN NNP -> noun, proper singular
# wants = VERB VBZ -> verb, 3rd person singular present
# a = DET DT -> determiner
# cracker = NOUN NN -> noun, singular or mass
# ------------------------------
# Think I should get off her first
# VERB PRON VERB VERB ADP ADJ ADJ
#
# Think = VERB VBP -> verb, non-3rd person singular present
# I = PRON PRP -> pronoun, personal
# should = VERB MD -> verb, modal auxiliary
# get = VERB VB -> verb, base form
# off = ADP IN -> conjunction, subordinating or preposition
# her = ADJ PRP$ -> pronoun, possessive
# first = ADJ JJ -> adjective
# ------------------------------
# Think she wants some water
# VERB PRON VERB DET NOUN
#
# Think = VERB VB -> verb, base form
# she = PRON PRP -> pronoun, personal
# wants = VERB VBZ -> verb, 3rd person singular present
# some = DET DT -> determiner
# water = NOUN NN -> noun, singular or mass
# ------------------------------
# To put out the blow torch
# PART VERB PART DET NOUN NOUN
#
# To = PART TO -> infinitival to
# put = VERB VB -> verb, base form
# out = PART RP -> adverb, particle
# the = DET DT -> determiner
# blow = NOUN NN -> noun, singular or mass
# torch = NOUN NN -> noun, singular or mass
# ------------------------------
#
#
#
# ------------------------------
# Polly said
# PROPN VERB
#
# Polly = PROPN NNP -> noun, proper singular
# said = VERB VBD -> verb, past tense
# ------------------------------
#
#
#
# ------------------------------
# Polly says her back hurts
# PROPN VERB ADJ NOUN VERB
#
# Polly = PROPN NNP -> noun, proper singular
# says = VERB VBZ -> verb, 3rd person singular present
# her = ADJ PRP$ -> pronoun, possessive
# back = NOUN NN -> noun, singular or mass
# hurts = VERB VBZ -> verb, 3rd person singular present
# ------------------------------
# She's just as bored as me
# PRON VERB ADV ADV ADJ ADP PRON
#
# She = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# just = ADV RB -> adverb
# as = ADV RB -> adverb
# bored = ADJ JJ -> adjective
# as = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# She caught me off my guard
# PRON VERB PRON ADP ADJ NOUN
#
# She = PRON PRP -> pronoun, personal
# caught = VERB VBD -> verb, past tense
# me = PRON PRP -> pronoun, personal
# off = ADP IN -> conjunction, subordinating or preposition
# my = ADJ PRP$ -> pronoun, possessive
# guard = NOUN NN -> noun, singular or mass
# ------------------------------
# 'Mazes me the will of instinct
# PUNCT NOUN PRON DET NOUN ADP NOUN
#
# ' = PUNCT `` -> opening quotation mark
# Mazes = NOUN NNS -> noun, plural
# me = PRON PRP -> pronoun, personal
# the = DET DT -> determiner
# will = NOUN NN -> noun, singular or mass
# of = ADP IN -> conjunction, subordinating or preposition
# instinct = NOUN NN -> noun, singular or mass
# ------------------------------
#
#
#
# ------------------------------
# Isn't me, have a seed
# VERB ADV PRON PUNCT VERB DET NOUN
#
# Is = VERB VBZ -> verb, 3rd person singular present
# n't = ADV RB -> adverb
# me = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# have = VERB VB -> verb, base form
# a = DET DT -> determiner
# seed = NOUN NN -> noun, singular or mass
# ------------------------------
# Let me clip, dirty wings
# VERB PRON VERB PUNCT ADJ NOUN
#
# Let = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# clip = VERB VB -> verb, base form
# , = PUNCT , -> punctuation mark, comma
# dirty = ADJ JJ -> adjective
# wings = NOUN NNS -> noun, plural
# ------------------------------
# Let me take a ride, cut yourself
# VERB PRON VERB DET NOUN PUNCT VERB PRON
#
# Let = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# take = VERB VB -> verb, base form
# a = DET DT -> determiner
# ride = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# cut = VERB VBD -> verb, past tense
# yourself = PRON PRP -> pronoun, personal
# ------------------------------
# Want some help, please myself
# VERB DET NOUN PUNCT INTJ PRON
#
# Want = VERB VB -> verb, base form
# some = DET DT -> determiner
# help = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# please = INTJ UH -> interjection
# myself = PRON PRP -> pronoun, personal
# ------------------------------
# Got some rope, have been told
# VERB DET NOUN PUNCT VERB VERB VERB
#
# Got = VERB VBD -> verb, past tense
# some = DET DT -> determiner
# rope = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# have = VERB VBP -> verb, non-3rd person singular present
# been = VERB VBN -> verb, past participle
# told = VERB VBN -> verb, past participle
# ------------------------------
# Promise you, have been true
# VERB PRON PUNCT VERB VERB ADJ
#
# Promise = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# have = VERB VBP -> verb, non-3rd person singular present
# been = VERB VBN -> verb, past participle
# true = ADJ JJ -> adjective
# ------------------------------
# Let me take a ride, cut yourself
# VERB PRON VERB DET NOUN PUNCT VERB PRON
#
# Let = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# take = VERB VB -> verb, base form
# a = DET DT -> determiner
# ride = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# cut = VERB VBD -> verb, past tense
# yourself = PRON PRP -> pronoun, personal
# ------------------------------
# Want some help, please myself
# VERB DET NOUN PUNCT INTJ PRON
#
# Want = VERB VB -> verb, base form
# some = DET DT -> determiner
# help = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# please = INTJ UH -> interjection
# myself = PRON PRP -> pronoun, personal
# ------------------------------
#
#
#
# ------------------------------
# Polly wants a cracker
# PROPN VERB DET NOUN
#
# Polly = PROPN NNP -> noun, proper singular
# wants = VERB VBZ -> verb, 3rd person singular present
# a = DET DT -> determiner
# cracker = NOUN NN -> noun, singular or mass
# ------------------------------
# Maybe she would like some food
# ADV PRON VERB VERB DET NOUN
#
# Maybe = ADV RB -> adverb
# she = PRON PRP -> pronoun, personal
# would = VERB MD -> verb, modal auxiliary
# like = VERB VB -> verb, base form
# some = DET DT -> determiner
# food = NOUN NN -> noun, singular or mass
# ------------------------------
# She asks me to untie her
# PRON VERB PRON PART VERB PRON
#
# She = PRON PRP -> pronoun, personal
# asks = VERB VBZ -> verb, 3rd person singular present
# me = PRON PRP -> pronoun, personal
# to = PART TO -> infinitival to
# untie = VERB VB -> verb, base form
# her = PRON PRP -> pronoun, personal
# ------------------------------
# Chase would be nice for a few
# PROPN VERB VERB ADJ ADP DET ADJ
#
# Chase = PROPN NNP -> noun, proper singular
# would = VERB MD -> verb, modal auxiliary
# be = VERB VB -> verb, base form
# nice = ADJ JJ -> adjective
# for = ADP IN -> conjunction, subordinating or preposition
# a = DET DT -> determiner
# few = ADJ JJ -> adjective
# ------------------------------

# %% [markdown]
# It seems to be quite good. Probably that's because we are looking at the song line by line (sentence by sentence). We believe that it is worth to have a look at what happens if we process a song as whole. However, we are doing this just for the sake of completeness because, while doing our feature engineering, we do not consider entire songs but just lines, one by one.

# %%
for token in lyrics:
    print(token.text, '=', token.pos_, '->', spacy.explain(token.pos_))
# Out:
# Polly = PROPN -> proper noun
# wants = VERB -> verb
# a = DET -> determiner
# cracker = NOUN -> noun
#
#  = SPACE -> space
# Think = VERB -> verb
# I = PRON -> pronoun
# should = VERB -> verb
# get = VERB -> verb
# off = ADP -> adposition
# her = ADJ -> adjective
# first = ADJ -> adjective
#
#  = SPACE -> space
# Think = VERB -> verb
# she = PRON -> pronoun
# wants = VERB -> verb
# some = DET -> determiner
# water = NOUN -> noun
#
#  = SPACE -> space
# To = PART -> particle
# put = VERB -> verb
# out = PART -> particle
# the = DET -> determiner
# blow = NOUN -> noun
# torch = NOUN -> noun
#
#
#  = SPACE -> space
# Polly = PROPN -> proper noun
# said = VERB -> verb
#
#
#  = SPACE -> space
# Polly = PROPN -> proper noun
# says = VERB -> verb
# her = ADJ -> adjective
# back = NOUN -> noun
# hurts = VERB -> verb
#
#  = SPACE -> space
# She = PRON -> pronoun
# 's = VERB -> verb
# just = ADV -> adverb
# as = ADV -> adverb
# bored = ADJ -> adjective
# as = ADP -> adposition
# me = PRON -> pronoun
#
#  = SPACE -> space
# She = PRON -> pronoun
# caught = VERB -> verb
# me = PRON -> pronoun
# off = ADP -> adposition
# my = ADJ -> adjective
# guard = NOUN -> noun
#
#  = SPACE -> space
# ' = PUNCT -> punctuation
# Mazes = NOUN -> noun
# me = PRON -> pronoun
# the = DET -> determiner
# will = NOUN -> noun
# of = ADP -> adposition
# instinct = NOUN -> noun
#
#
#  = SPACE -> space
# Is = VERB -> verb
# n't = ADV -> adverb
# me = PRON -> pronoun
# , = PUNCT -> punctuation
# have = VERB -> verb
# a = DET -> determiner
# seed = NOUN -> noun
#
#  = SPACE -> space
# Let = VERB -> verb
# me = PRON -> pronoun
# clip = VERB -> verb
# , = PUNCT -> punctuation
# dirty = ADJ -> adjective
# wings = NOUN -> noun
#
#  = SPACE -> space
# Let = VERB -> verb
# me = PRON -> pronoun
# take = VERB -> verb
# a = DET -> determiner
# ride = NOUN -> noun
# , = PUNCT -> punctuation
# cut = VERB -> verb
# yourself = PRON -> pronoun
#
#  = SPACE -> space
# Want = VERB -> verb
# some = DET -> determiner
# help = NOUN -> noun
# , = PUNCT -> punctuation
# please = INTJ -> interjection
# myself = PRON -> pronoun
#
#  = SPACE -> space
# Got = VERB -> verb
# some = DET -> determiner
# rope = NOUN -> noun
# , = PUNCT -> punctuation
# have = VERB -> verb
# been = VERB -> verb
# told = VERB -> verb
#
#  = SPACE -> space
# Promise = PROPN -> proper noun
# you = PRON -> pronoun
# , = PUNCT -> punctuation
# have = VERB -> verb
# been = VERB -> verb
# true = ADJ -> adjective
#
#  = SPACE -> space
# Let = VERB -> verb
# me = PRON -> pronoun
# take = VERB -> verb
# a = DET -> determiner
# ride = NOUN -> noun
# , = PUNCT -> punctuation
# cut = VERB -> verb
# yourself = PRON -> pronoun
#
#  = SPACE -> space
# Want = VERB -> verb
# some = DET -> determiner
# help = NOUN -> noun
# , = PUNCT -> punctuation
# please = INTJ -> interjection
# myself = PRON -> pronoun
#
#
#  = SPACE -> space
# Polly = PROPN -> proper noun
# wants = VERB -> verb
# a = DET -> determiner
# cracker = NOUN -> noun
#
#  = SPACE -> space
# Maybe = ADV -> adverb
# she = PRON -> pronoun
# would = VERB -> verb
# like = VERB -> verb
# some = DET -> determiner
# food = NOUN -> noun
#
#  = SPACE -> space
# She = PRON -> pronoun
# asks = VERB -> verb
# me = PRON -> pronoun
# to = PART -> particle
# untie = VERB -> verb
# her = ADJ -> adjective
#
#  = SPACE -> space
# Chase = PROPN -> proper noun
# would = VERB -> verb
# be = VERB -> verb
# nice = ADJ -> adjective
# for = ADP -> adposition
# a = DET -> determiner
# few = ADJ -> adjective

# %% [markdown]
# The results seems to be totally the same as those we obtained above. Therefore we can conclude that there are no particular issues in analyzing a song as whole (which we do not do by the way) rather than analyzing it line by line.

# %% [markdown]
# ## Maybe not with a 'weirder' song?

# %% [markdown]
# We believe that analyzing "Polly" from Nirvana is not exhaustive as it does not contain particularly strange words, nor slangs, nor abbreviations. Among the songs available in MoodyLyrics we found one of them which is particularly long and contains several slangs and abbreviations. It is "Kiss You Back" from Underground Kiss ([link](https://www.youtube.com/watch?v=szjoplYtqW4)).
#
# We'll repeat the same things done before (read and duplicate parts elimination).

# %%
path = 'ml_lyrics/happy_Digital Underground_Kiss You Back'

# %%
with open(path, 'r') as f:
    lyrics = f.read()
    print(lyrics)
# Out:
# Shimmy shimmy cocoa-pop
# Shimmy shimmy cocoa-pop
# Shimmy shimmy cocoa-pop
# Shimmy shimmy cocoa-pop
# We-we chocolate cross-over
# Yeah, we chocolate cross-over
# See me cocoa might go pop
# I'm cocoa and I might go pop
#
# Now it's about time that I cleared this
# So pardon me miss
# But I'd like for you to hear this
# If you kiss me then I'll kiss you back
# You see, I feel real good inside, and it's just from your nearness
# There's no need for you to fear this
# Kiss me, I'll kiss you back
# Mmmm-<kiss>
#
# Well ya look kinda cute to me
# I think we can achieve this
# Plus you act like you need this
# Kiss me and I'll kiss you back
# You act real fly
# Money-B's not buyin' it
# Quit denyin' it
# You're better off tryin' it
# Freak me girl and I'll freak you back
# (Duh nuh nuh nuh nuh nuh nuuuuh)
#
# Through any kinda weather
# Will me and you forever
# Stay together
# Well I just don't know
# But I'll tell ya what though
# If you kiss me then I'll kiss you back
# (Kiss you back)
# And I guess you wanna know if I'm gonna be around
# I ain't sure but I'll tell you what I do know
# If you kiss me then I'll kiss you back
# (Kiss you back)
# Awright, let's do this
#
# If you kiss me then I'll kiss you back
# Yeah, Kiss me and I'll kiss you back
# If you kiss me then I'll kiss you back
# You with it? 'cause if you with it, I'm with it, yo
# If you kiss me then I'll kiss you back
# Yeah, mmm-<kiss>
# Just kiss me then I'll kiss you back
# I'll kiss you back, I'll kiss you back
#
# Now I'm hopin' that you hear me
# 'Cause I love it when you're near me
# And I'm tellin' you sincerely
# That if you kiss me girl I'll kiss you back
# 'Cause I really really really like you
# And I just want to make it clear
# <Clears throat>
# We're gonna keep it fair and square
# Kiss me and I'll kiss you back
#
# Yo it's not funny!
# Real cute is what you say to me
# But any other way you play me
# If you love me then I'll love you back
# When you say I get the most out of this it kind of bothers me
# A fair exchange and no robbery
# Love me girl and I'll love you back
#
# Now I'm hopin that you hear me
# 'Cause I love it when you're near me
# And I know you know I knew this
# So I guess that we can do this
# Awright, sing it with me again, c'mon
#
# If you kiss me then I'll kiss you back
# Come on, keep it going
# If you kiss me then I'll kiss you back
# Yeah, ladies?
# If you love me boy I'll love you back
# Oh yeah? Yo I'm with it!
# If you kiss me then I'll kiss you back
# Awright, awright that's cool, now let's change it up a little
#
# If you play with my tummy I'll tickle your feet
# You know?
# If you touch me here I'll touch you there
# Yeah, put lotion on me
# If you kiss me then I'll kiss you back
# I'll kiss you back
# If you love me girl I'll love you back
# I'll love you back
#
# We know what you go though
# Sometimes we put you down
# People treat you coldly
# They know you sleep around
# We never want to disrespect you
# And tell anyone in town
# But if you love me then I'll love you back
# I'm askin' if you're down
#
# I'm hopin' that you hear me 'cause I love it when you're near me
#
# If you kiss me then I'll kiss you back
# I'll kiss you back
# You know I know you knew this so I guess that we could do this
# If you kiss me then I'll kiss you back
# You know what I'm sayin'?
# I mean if it's a deal to you it's a deal to me, but yo
# Kiss me then I'll kiss you back
# Yo let's kick it one more time, come on
# Kick it
#
# If you kiss me then I'll kiss you back
# Kiss me
# If you kiss me then I'll kiss you back
# And I'll kiss you back
# If you kiss me then I'll kiss you back
# If you play with my feet I'll tickle your tummy
# If you love me boy I'll love you back
# Yeah, I like it when the girls do it
# If you love me boy I'll love you back
# Come one ladies, one more time, kick it
# If you love me boy I'll love you back
#
# 'Cause if you kiss me then I'll kiss you back
# But if you hit me then I'll hit you back
# Smack me and I'll smack you back
# If you scratch me here I'll scratch you there
# Aww, put lotion on me
# If you kiss me then I'll kiss you back
#
# If you kiss me then I'll kiss you back
# If you kiss me girl I'll kiss you back
# If you touch me here I'll thouch you there
# Touch me here, baby, and I'll touch you there
# If you kiss me then I'll kiss you back
# <Laughs>
#
# Yeah! Yo this is pumpin'!
# Yo Shock this is pumpin' man, this sounds like somethin' I'd do!
# I hear ya, I hear ya Hump!
# You know what I'm sayin'?
# Yeah.
# 'Cept I'd do it like this:
# Hit it girls
#
# If you pinch my nose I'll play with your toes
# You know what I'm sayin'?
# Right, right, right
# If you look real cutie I'll play with your booty
# Yeah
# Yeah
# Check it, yeah
# Yo, but would ya
# If you hold my nuts I'll
# Awright, that's enough! That's enough!
# What, what man? I ain't...
# No, no Hump, come on man, no, no
# Awright, awright, awright
# Let's just keep it cool, you know what I'm sayin'?
#
# If you kiss me then I'll kiss you back
# If you kiss me then I'll kiss you back
# Hold my nose! Uh-huh
# If you kiss me then I'll kiss you back
# Jus't havin' fun with it, man, know what I'm sayin'?
# If you kiss me then I'll kiss you back
# Kiss me then I'll kiss you back
# Awright, heh heh
#
# Shimmy shimmy cocoa-pop
# We-we chocolate cross-over
# See me cocoa might go pop
# Shimmy shimmy cocoa pop
#
# We chocolate cross-over
# We chocolate might cross over
# See me cocoa might go pop
# I'm cocoa and I might go pop
# See me cocoa might go pop
# See me? I'm cocoa, and I might go pop
# See me cocoa might go pop
# Yeah, we cocoa and we might go pop
#
# See me cocoa might go pop
# See me cocoa might go pop
# See me cocoa might go pop
# See me See me cocoa might go pop go pop
# See me cocoa might go pop
# Me cocoa and I might go pop
# Hah hah hah hah hah
# See me cocoa might go pop

# %%
parts = lyrics.split('\n\n')
print('We had {} parts'.format(len(parts)))
parts = list(set(parts))
print('Now we have {} parts'.format(len(parts)))
# Out:
# We had 22 parts
# Now we have 22 parts

# %% [markdown]
# Nothing changed this time so we do not need to read the song again.

# %%
lyrics = nlp(lyrics)
lines = get_lines()

# %%
# Let's have a look at the first line
describe_line(lines[0])
# Out:
# Shimmy shimmy cocoa-pop
# VERB VERB NOUN PUNCT NOUN
#
# Shimmy = VERB VB -> verb, base form
# shimmy = VERB VB -> verb, base form
# cocoa = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# pop = NOUN NN -> noun, singular or mass

# %% [markdown]
# The only thing to note is that cocoa-pop is not treated as a single token as we would expect. Instead, the '-' is treated as self-standing token, which causes 'coca-pop' to split.
#
# Apart from this, the first line does not present any problem. Let's analyze all lines, one by one and see if we have problems. Before doing that, since we will analyze this song just line by line (we saw that analyzing it as whole does not change anything) we will firstly remove all duplicate lines.

# %%
lines = list(set(lines))
# Also drop empty lines
lines = [line for line in lines if len(line) > 0]

# %%
for line in lines:
    describe_line(line)
    print('-'*30)
# Out:
# If you hold my nuts I'll
# ADP PRON VERB ADJ NOUN PRON VERB
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# hold = VERB VBP -> verb, non-3rd person singular present
# my = ADJ PRP$ -> pronoun, possessive
# nuts = NOUN NNS -> noun, plural
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# ------------------------------
# You act real fly
# PRON VERB ADV NOUN
#
# You = PRON PRP -> pronoun, personal
# act = VERB VBP -> verb, non-3rd person singular present
# real = ADV RB -> adverb
# fly = NOUN NN -> noun, singular or mass
# ------------------------------
# Yeah, we chocolate cross-over
# INTJ PUNCT PRON VERB NOUN PUNCT PART
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# we = PRON PRP -> pronoun, personal
# chocolate = VERB VBP -> verb, non-3rd person singular present
# cross = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# over = PART RP -> adverb, particle
# ------------------------------
# <Clears throat>
# X VERB NOUN X
#
# < = X XX -> unknown
# Clears = VERB VBZ -> verb, 3rd person singular present
# throat = NOUN NN -> noun, singular or mass
# > = X XX -> unknown
# ------------------------------
# Jus't havin' fun with it, man, know what I'm sayin'?
# NOUN VERB NOUN ADP PRON PUNCT INTJ PUNCT VERB NOUN PRON VERB VERB PUNCT PUNCT
#
# Jus't = NOUN NNS -> noun, plural
# havin' = VERB VBG -> verb, gerund or present participle
# fun = NOUN NN -> noun, singular or mass
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# man = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# know = VERB VB -> verb, base form
# what = NOUN WP -> wh-pronoun, personal
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# sayin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# (Duh nuh nuh nuh nuh nuh nuuuuh)
# PUNCT INTJ VERB NOUN NOUN NOUN NOUN NOUN PUNCT
#
# ( = PUNCT -LRB- -> left round bracket
# Duh = INTJ UH -> interjection
# nuh = VERB VB -> verb, base form
# nuh = NOUN NN -> noun, singular or mass
# nuh = NOUN NN -> noun, singular or mass
# nuh = NOUN NN -> noun, singular or mass
# nuh = NOUN NN -> noun, singular or mass
# nuuuuh = NOUN NN -> noun, singular or mass
# ) = PUNCT -RRB- -> right round bracket
# ------------------------------
# We know what you go though
# PRON VERB NOUN PRON VERB ADV
#
# We = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# what = NOUN WP -> wh-pronoun, personal
# you = PRON PRP -> pronoun, personal
# go = VERB VBP -> verb, non-3rd person singular present
# though = ADV RB -> adverb
# ------------------------------
# If you touch me here I'll thouch you there
# ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# touch = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# here = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# thouch = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# there = ADV RB -> adverb
# ------------------------------
# Awright, let's do this
# INTJ PUNCT VERB PRON VERB DET
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# let = VERB VB -> verb, base form
# 's = PRON PRP -> pronoun, personal
# do = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# I mean if it's a deal to you it's a deal to me, but yo
# PRON VERB ADP PRON VERB DET NOUN ADP PRON PRON VERB DET NOUN ADP PRON PUNCT CCONJ INTJ
#
# I = PRON PRP -> pronoun, personal
# mean = VERB VBP -> verb, non-3rd person singular present
# if = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# a = DET DT -> determiner
# deal = NOUN NN -> noun, singular or mass
# to = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# it = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# a = DET DT -> determiner
# deal = NOUN NN -> noun, singular or mass
# to = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# but = CCONJ CC -> conjunction, coordinating
# yo = INTJ UH -> interjection
# ------------------------------
# I'm cocoa and I might go pop
# PRON VERB NOUN CCONJ PRON VERB VERB VERB
#
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# cocoa = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# ------------------------------
# Check it, yeah
# VERB PRON PUNCT INTJ
#
# Check = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# yeah = INTJ UH -> interjection
# ------------------------------
# Awright, awright, awright
# INTJ PUNCT INTJ PUNCT INTJ
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# awright = INTJ UH -> interjection
# ------------------------------
# If you love me girl I'll love you back
# ADP PRON VERB PRON NOUN PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# girl = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# 'Cause if you kiss me then I'll kiss you back
# ADP ADP PRON VERB PRON ADV PRON VERB VERB PRON PART
#
# 'Cause = ADP IN -> conjunction, subordinating or preposition
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# kiss = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# Kick it
# VERB PRON
#
# Kick = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# ------------------------------
# And I just want to make it clear
# CCONJ PRON ADV VERB PART VERB PRON ADJ
#
# And = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# just = ADV RB -> adverb
# want = VERB VBP -> verb, non-3rd person singular present
# to = PART TO -> infinitival to
# make = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# clear = ADJ JJ -> adjective
# ------------------------------
# Awright, that's enough! That's enough!
# INTJ PUNCT DET VERB ADJ PUNCT DET VERB ADJ PUNCT
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# that = DET DT -> determiner
# 's = VERB VBZ -> verb, 3rd person singular present
# enough = ADJ JJ -> adjective
# ! = PUNCT . -> punctuation mark, sentence closer
# That = DET DT -> determiner
# 's = VERB VBZ -> verb, 3rd person singular present
# enough = ADJ JJ -> adjective
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# 'Cause I love it when you're near me
# ADP PRON VERB PRON ADV PRON VERB ADP PRON
#
# 'Cause = ADP IN -> conjunction, subordinating or preposition
# I = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# it = PRON PRP -> pronoun, personal
# when = ADV WRB -> wh-adverb
# you = PRON PRP -> pronoun, personal
# 're = VERB VBP -> verb, non-3rd person singular present
# near = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# And I know you know I knew this
# CCONJ PRON VERB PRON VERB PRON VERB DET
#
# And = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# I = PRON PRP -> pronoun, personal
# knew = VERB VBD -> verb, past tense
# this = DET DT -> determiner
# ------------------------------
# I'll kiss you back
# PRON VERB VERB PRON PART
#
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# There's no need for you to fear this
# ADV VERB DET NOUN ADP PRON PART VERB DET
#
# There = ADV EX -> existential there
# 's = VERB VBZ -> verb, 3rd person singular present
# no = DET DT -> determiner
# need = NOUN NN -> noun, singular or mass
# for = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# to = PART TO -> infinitival to
# fear = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# They know you sleep around
# PRON VERB PRON VERB ADV
#
# They = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# sleep = VERB VBP -> verb, non-3rd person singular present
# around = ADV RB -> adverb
# ------------------------------
# I'm askin' if you're down
# PRON VERB VERB PUNCT ADP PRON VERB ADV
#
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# askin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# 're = VERB VBP -> verb, non-3rd person singular present
# down = ADV RB -> adverb
# ------------------------------
# See me? I'm cocoa, and I might go pop
# VERB PRON PUNCT PRON VERB NOUN PUNCT CCONJ PRON VERB VERB VERB
#
# See = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# ? = PUNCT . -> punctuation mark, sentence closer
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# cocoa = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# ------------------------------
# (Kiss you back)
# PUNCT VERB PRON PART PUNCT
#
# ( = PUNCT -LRB- -> left round bracket
# Kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ) = PUNCT -RRB- -> right round bracket
# ------------------------------
# Kiss me then I'll kiss you back
# VERB PRON ADV PRON VERB VERB PRON PART
#
# Kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# Well ya look kinda cute to me
# INTJ PRON VERB ADV ADJ ADP PRON
#
# Well = INTJ UH -> interjection
# ya = PRON PRP -> pronoun, personal
# look = VERB VBP -> verb, non-3rd person singular present
# kinda = ADV RB -> adverb
# cute = ADJ JJ -> adjective
# to = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# Yeah, mmm-<kiss>
# INTJ PUNCT VERB X
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# mmm-<kiss = VERB VB -> verb, base form
# > = X XX -> unknown
# ------------------------------
# Yeah, Kiss me and I'll kiss you back
# INTJ PUNCT VERB PRON CCONJ PRON VERB VERB PRON PART
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# Kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# So pardon me miss
# CCONJ VERB PRON VERB
#
# So = CCONJ CC -> conjunction, coordinating
# pardon = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# miss = VERB VB -> verb, base form
# ------------------------------
# Now I'm hopin' that you hear me
# ADV PRON VERB NOUN PUNCT ADP PRON VERB PRON
#
# Now = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# hopin = NOUN NN -> noun, singular or mass
# ' = PUNCT '' -> closing quotation mark
# that = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# hear = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# ------------------------------
# If you look real cutie I'll play with your booty
# ADP PRON VERB ADJ NOUN PRON VERB VERB ADP ADJ NOUN
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# look = VERB VBP -> verb, non-3rd person singular present
# real = ADJ JJ -> adjective
# cutie = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# play = VERB VB -> verb, base form
# with = ADP IN -> conjunction, subordinating or preposition
# your = ADJ PRP$ -> pronoun, possessive
# booty = NOUN NN -> noun, singular or mass
# ------------------------------
# Shimmy shimmy cocoa-pop
# VERB VERB NOUN PUNCT NOUN
#
# Shimmy = VERB VB -> verb, base form
# shimmy = VERB VB -> verb, base form
# cocoa = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# pop = NOUN NN -> noun, singular or mass
# ------------------------------
# You see, I feel real good inside, and it's just from your nearness
# PRON VERB PUNCT PRON VERB ADV ADJ ADV PUNCT CCONJ PRON VERB ADV ADP ADJ NOUN
#
# You = PRON PRP -> pronoun, personal
# see = VERB VBP -> verb, non-3rd person singular present
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# feel = VERB VBP -> verb, non-3rd person singular present
# real = ADV RB -> adverb
# good = ADJ JJ -> adjective
# inside = ADV RB -> adverb
# , = PUNCT , -> punctuation mark, comma
# and = CCONJ CC -> conjunction, coordinating
# it = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# just = ADV RB -> adverb
# from = ADP IN -> conjunction, subordinating or preposition
# your = ADJ PRP$ -> pronoun, possessive
# nearness = NOUN NN -> noun, singular or mass
# ------------------------------
# <Laughs>
# X VERB X
#
# < = X XX -> unknown
# Laughs = VERB VBZ -> verb, 3rd person singular present
# > = X XX -> unknown
# ------------------------------
# Aww, put lotion on me
# PROPN PUNCT VERB NOUN ADP PRON
#
# Aww = PROPN NNP -> noun, proper singular
# , = PUNCT , -> punctuation mark, comma
# put = VERB VBD -> verb, past tense
# lotion = NOUN NN -> noun, singular or mass
# on = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# You're better off tryin' it
# PRON VERB ADJ PART NOUN PUNCT PRON
#
# You = PRON PRP -> pronoun, personal
# 're = VERB VBP -> verb, non-3rd person singular present
# better = ADJ JJR -> adjective, comparative
# off = PART RP -> adverb, particle
# tryin = NOUN NN -> noun, singular or mass
# ' = PUNCT '' -> closing quotation mark
# it = PRON PRP -> pronoun, personal
# ------------------------------
# Oh yeah? Yo I'm with it!
# INTJ INTJ PUNCT INTJ PRON VERB ADP PRON PUNCT
#
# Oh = INTJ UH -> interjection
# yeah = INTJ UH -> interjection
# ? = PUNCT . -> punctuation mark, sentence closer
# Yo = INTJ UH -> interjection
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Me cocoa and I might go pop
# PRON NOUN CCONJ PRON VERB VERB VERB
#
# Me = PRON PRP -> pronoun, personal
# cocoa = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# ------------------------------
# Awright, awright that's cool, now let's change it up a little
# INTJ PUNCT INTJ DET VERB ADJ PUNCT ADV VERB PRON VERB PRON PART DET ADJ
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# awright = INTJ UH -> interjection
# that = DET DT -> determiner
# 's = VERB VBZ -> verb, 3rd person singular present
# cool = ADJ JJ -> adjective
# , = PUNCT , -> punctuation mark, comma
# now = ADV RB -> adverb
# let = VERB VB -> verb, base form
# 's = PRON PRP -> pronoun, personal
# change = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# up = PART RP -> adverb, particle
# a = DET DT -> determiner
# little = ADJ JJ -> adjective
# ------------------------------
# A fair exchange and no robbery
# DET ADJ NOUN CCONJ DET NOUN
#
# A = DET DT -> determiner
# fair = ADJ JJ -> adjective
# exchange = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# no = DET DT -> determiner
# robbery = NOUN NN -> noun, singular or mass
# ------------------------------
# Sometimes we put you down
# ADV PRON VERB PRON PART
#
# Sometimes = ADV RB -> adverb
# we = PRON PRP -> pronoun, personal
# put = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# down = PART RP -> adverb, particle
# ------------------------------
# And I'm tellin' you sincerely
# CCONJ PRON VERB VERB PUNCT PRON ADV
#
# And = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# tellin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# you = PRON PRP -> pronoun, personal
# sincerely = ADV RB -> adverb
# ------------------------------
# We're gonna keep it fair and square
# PRON VERB VERB PART VERB PRON ADJ CCONJ ADJ
#
# We = PRON PRP -> pronoun, personal
# 're = VERB VBP -> verb, non-3rd person singular present
# gon = VERB VBG -> verb, gerund or present participle
# na = PART TO -> infinitival to
# keep = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# fair = ADJ JJ -> adjective
# and = CCONJ CC -> conjunction, coordinating
# square = ADJ JJ -> adjective
# ------------------------------
# Through any kinda weather
# ADP DET ADJ NOUN
#
# Through = ADP IN -> conjunction, subordinating or preposition
# any = DET DT -> determiner
# kinda = ADJ JJ -> adjective
# weather = NOUN NN -> noun, singular or mass
# ------------------------------
# Yeah! Yo this is pumpin'!
# INTJ PUNCT INTJ DET VERB ADJ PUNCT PUNCT
#
# Yeah = INTJ UH -> interjection
# ! = PUNCT . -> punctuation mark, sentence closer
# Yo = INTJ UH -> interjection
# this = DET DT -> determiner
# is = VERB VBZ -> verb, 3rd person singular present
# pumpin = ADJ JJ -> adjective
# ' = PUNCT '' -> closing quotation mark
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# 'Cause I really really really like you
# ADP PRON ADV ADV ADV ADP PRON
#
# 'Cause = ADP IN -> conjunction, subordinating or preposition
# I = PRON PRP -> pronoun, personal
# really = ADV RB -> adverb
# really = ADV RB -> adverb
# really = ADV RB -> adverb
# like = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# ------------------------------
# We chocolate might cross over
# PRON NOUN VERB VERB PART
#
# We = PRON PRP -> pronoun, personal
# chocolate = NOUN NN -> noun, singular or mass
# might = VERB MD -> verb, modal auxiliary
# cross = VERB VB -> verb, base form
# over = PART RP -> adverb, particle
# ------------------------------
# Money-B's not buyin' it
# NOUN PUNCT NOUN PART ADV NOUN PUNCT PRON
#
# Money = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# B = NOUN NN -> noun, singular or mass
# 's = PART POS -> possessive ending
# not = ADV RB -> adverb
# buyin = NOUN NN -> noun, singular or mass
# ' = PUNCT '' -> closing quotation mark
# it = PRON PRP -> pronoun, personal
# ------------------------------
# Come one ladies, one more time, kick it
# VERB NUM NOUN PUNCT NUM ADJ NOUN PUNCT VERB PRON
#
# Come = VERB VB -> verb, base form
# one = NUM CD -> cardinal number
# ladies = NOUN NNS -> noun, plural
# , = PUNCT , -> punctuation mark, comma
# one = NUM CD -> cardinal number
# more = ADJ JJR -> adjective, comparative
# time = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# kick = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# ------------------------------
# Kiss me and I'll kiss you back
# VERB PRON CCONJ PRON VERB VERB PRON PART
#
# Kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# If you scratch me here I'll scratch you there
# ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# scratch = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# here = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# scratch = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# there = ADV RB -> adverb
# ------------------------------
# You with it? 'cause if you with it, I'm with it, yo
# PRON ADP PRON PUNCT ADP ADP PRON ADP PRON PUNCT PRON VERB ADP PRON PUNCT INTJ
#
# You = PRON PRP -> pronoun, personal
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# ? = PUNCT . -> punctuation mark, sentence closer
# 'cause = ADP IN -> conjunction, subordinating or preposition
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# yo = INTJ UH -> interjection
# ------------------------------
# Yeah, we cocoa and we might go pop
# INTJ PUNCT PRON VERB CCONJ PRON VERB VERB VERB
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# we = PRON PRP -> pronoun, personal
# cocoa = VERB VBP -> verb, non-3rd person singular present
# and = CCONJ CC -> conjunction, coordinating
# we = PRON PRP -> pronoun, personal
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# ------------------------------
# Well I just don't know
# INTJ PRON ADV VERB ADV VERB
#
# Well = INTJ UH -> interjection
# I = PRON PRP -> pronoun, personal
# just = ADV RB -> adverb
# do = VERB VBP -> verb, non-3rd person singular present
# n't = ADV RB -> adverb
# know = VERB VB -> verb, base form
# ------------------------------
# Yeah, I like it when the girls do it
# INTJ PUNCT PRON VERB PRON ADV DET NOUN VERB PRON
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# like = VERB VBP -> verb, non-3rd person singular present
# it = PRON PRP -> pronoun, personal
# when = ADV WRB -> wh-adverb
# the = DET DT -> determiner
# girls = NOUN NNS -> noun, plural
# do = VERB VBP -> verb, non-3rd person singular present
# it = PRON PRP -> pronoun, personal
# ------------------------------
# Right, right, right
# INTJ PUNCT INTJ PUNCT ADJ
#
# Right = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# right = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# right = ADJ JJ -> adjective
# ------------------------------
# Hah hah hah hah hah
# INTJ INTJ INTJ INTJ INTJ
#
# Hah = INTJ UH -> interjection
# hah = INTJ UH -> interjection
# hah = INTJ UH -> interjection
# hah = INTJ UH -> interjection
# hah = INTJ UH -> interjection
# ------------------------------
# But I'll tell ya what though
# CCONJ PRON VERB VERB PRON NOUN ADP
#
# But = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# tell = VERB VB -> verb, base form
# ya = PRON PRP -> pronoun, personal
# what = NOUN WP -> wh-pronoun, personal
# though = ADP IN -> conjunction, subordinating or preposition
# ------------------------------
# But any other way you play me
# CCONJ DET ADJ NOUN PRON VERB PRON
#
# But = CCONJ CC -> conjunction, coordinating
# any = DET DT -> determiner
# other = ADJ JJ -> adjective
# way = NOUN NN -> noun, singular or mass
# you = PRON PRP -> pronoun, personal
# play = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# ------------------------------
# But I'd like for you to hear this
# CCONJ PRON VERB VERB ADP PRON PART VERB DET
#
# But = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'd = VERB MD -> verb, modal auxiliary
# like = VERB VB -> verb, base form
# for = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# to = PART TO -> infinitival to
# hear = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# You know what I'm sayin'?
# PRON VERB NOUN PRON VERB VERB PUNCT PUNCT
#
# You = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# what = NOUN WP -> wh-pronoun, personal
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# sayin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# If you play with my feet I'll tickle your tummy
# ADP PRON VERB ADP ADJ NOUN PRON VERB VERB ADJ NOUN
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# play = VERB VBP -> verb, non-3rd person singular present
# with = ADP IN -> conjunction, subordinating or preposition
# my = ADJ PRP$ -> pronoun, possessive
# feet = NOUN NNS -> noun, plural
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# tickle = VERB VB -> verb, base form
# your = ADJ PRP$ -> pronoun, possessive
# tummy = NOUN NN -> noun, singular or mass
# ------------------------------
# If you love me then I'll love you back
# ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# So I guess that we can do this
# ADV PRON VERB ADP PRON VERB VERB DET
#
# So = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# guess = VERB VBP -> verb, non-3rd person singular present
# that = ADP IN -> conjunction, subordinating or preposition
# we = PRON PRP -> pronoun, personal
# can = VERB MD -> verb, modal auxiliary
# do = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# Kiss me, I'll kiss you back
# VERB PRON PUNCT PRON VERB VERB PRON PART
#
# Kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# You know?
# PRON VERB PUNCT
#
# You = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Kiss me
# VERB PRON
#
# Kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# ------------------------------
# Yeah
# INTJ
#
# Yeah = INTJ UH -> interjection
# ------------------------------
# Now I'm hopin that you hear me
# ADV PRON VERB NOUN ADP PRON VERB PRON
#
# Now = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# hopin = NOUN NN -> noun, singular or mass
# that = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# hear = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# ------------------------------
# And tell anyone in town
# CCONJ VERB NOUN ADP NOUN
#
# And = CCONJ CC -> conjunction, coordinating
# tell = VERB VB -> verb, base form
# anyone = NOUN NN -> noun, singular or mass
# in = ADP IN -> conjunction, subordinating or preposition
# town = NOUN NN -> noun, singular or mass
# ------------------------------
# I'm hopin' that you hear me 'cause I love it when you're near me
# PRON VERB NOUN PUNCT ADP PRON VERB PRON ADP PRON VERB PRON ADV PRON VERB ADP PRON
#
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# hopin = NOUN NN -> noun, singular or mass
# ' = PUNCT '' -> closing quotation mark
# that = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# hear = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# 'cause = ADP IN -> conjunction, subordinating or preposition
# I = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# it = PRON PRP -> pronoun, personal
# when = ADV WRB -> wh-adverb
# you = PRON PRP -> pronoun, personal
# 're = VERB VBP -> verb, non-3rd person singular present
# near = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# If you play with my tummy I'll tickle your feet
# ADP PRON VERB ADP ADJ NOUN PRON VERB VERB ADJ NOUN
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# play = VERB VBP -> verb, non-3rd person singular present
# with = ADP IN -> conjunction, subordinating or preposition
# my = ADJ PRP$ -> pronoun, possessive
# tummy = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# tickle = VERB VB -> verb, base form
# your = ADJ PRP$ -> pronoun, possessive
# feet = NOUN NNS -> noun, plural
# ------------------------------
# Smack me and I'll smack you back
# VERB PRON CCONJ PRON VERB VERB PRON ADV
#
# Smack = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# smack = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# And I'll kiss you back
# CCONJ PRON VERB VERB PRON PART
#
# And = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# Touch me here, baby, and I'll touch you there
# VERB PRON ADV PUNCT NOUN PUNCT CCONJ PRON VERB VERB PRON ADV
#
# Touch = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# here = ADV RB -> adverb
# , = PUNCT , -> punctuation mark, comma
# baby = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# touch = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# there = ADV RB -> adverb
# ------------------------------
# See me cocoa might go pop
# VERB PRON NOUN VERB VERB VERB
#
# See = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# cocoa = NOUN NN -> noun, singular or mass
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# ------------------------------
# Yeah, put lotion on me
# INTJ PUNCT VERB NOUN ADP PRON
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# put = VERB VB -> verb, base form
# lotion = NOUN NN -> noun, singular or mass
# on = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# If you kiss me then I'll kiss you back
# ADP PRON VERB PRON ADV PRON VERB VERB PRON PART
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# kiss = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# But if you hit me then I'll hit you back
# CCONJ ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# But = CCONJ CC -> conjunction, coordinating
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# hit = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# hit = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# That if you kiss me girl I'll kiss you back
# ADP ADP PRON VERB PRON NOUN PRON VERB VERB PRON PART
#
# That = ADP IN -> conjunction, subordinating or preposition
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# kiss = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# girl = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# If you love me boy I'll love you back
# ADP PRON VERB PRON INTJ PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# boy = INTJ UH -> interjection
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# If you pinch my nose I'll play with your toes
# ADP PRON VERB ADJ NOUN PRON VERB VERB ADP ADJ NOUN
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# pinch = VERB VBP -> verb, non-3rd person singular present
# my = ADJ PRP$ -> pronoun, possessive
# nose = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# play = VERB VB -> verb, base form
# with = ADP IN -> conjunction, subordinating or preposition
# your = ADJ PRP$ -> pronoun, possessive
# toes = NOUN NNS -> noun, plural
# ------------------------------
# Yo it's not funny!
# INTJ PRON VERB ADV ADJ PUNCT
#
# Yo = INTJ UH -> interjection
# it = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# not = ADV RB -> adverb
# funny = ADJ JJ -> adjective
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Come on, keep it going
# VERB PART PUNCT VERB PRON VERB
#
# Come = VERB VB -> verb, base form
# on = PART RP -> adverb, particle
# , = PUNCT , -> punctuation mark, comma
# keep = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# going = VERB VBG -> verb, gerund or present participle
# ------------------------------
# Yo, but would ya
# INTJ PUNCT CCONJ VERB PRON
#
# Yo = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# but = CCONJ CC -> conjunction, coordinating
# would = VERB MD -> verb, modal auxiliary
# ya = PRON PRP -> pronoun, personal
# ------------------------------
# Awright, sing it with me again, c'mon
# INTJ PUNCT VERB PRON ADP PRON ADV PUNCT INTJ
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# sing = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# with = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# again = ADV RB -> adverb
# , = PUNCT , -> punctuation mark, comma
# c'mon = INTJ UH -> interjection
# ------------------------------
# Stay together
# VERB ADV
#
# Stay = VERB VB -> verb, base form
# together = ADV RB -> adverb
# ------------------------------
# Hit it girls
# VERB PRON NOUN
#
# Hit = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# girls = NOUN NNS -> noun, plural
# ------------------------------
# Yo let's kick it one more time, come on
# PROPN VERB PRON VERB PRON NUM ADJ NOUN PUNCT VERB PART
#
# Yo = PROPN NNP -> noun, proper singular
# let = VERB VB -> verb, base form
# 's = PRON PRP -> pronoun, personal
# kick = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# one = NUM CD -> cardinal number
# more = ADJ JJR -> adjective, comparative
# time = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# come = VERB VB -> verb, base form
# on = PART RP -> adverb, particle
# ------------------------------
# Just kiss me then I'll kiss you back
# ADV VERB PRON ADV PRON VERB VERB PRON PART
#
# Just = ADV RB -> adverb
# kiss = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# I think we can achieve this
# PRON VERB PRON VERB VERB DET
#
# I = PRON PRP -> pronoun, personal
# think = VERB VBP -> verb, non-3rd person singular present
# we = PRON PRP -> pronoun, personal
# can = VERB MD -> verb, modal auxiliary
# achieve = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# Love me girl and I'll love you back
# VERB PRON NOUN CCONJ PRON VERB VERB PRON ADV
#
# Love = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# girl = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# You know I know you knew this so I guess that we could do this
# PRON VERB PRON VERB PRON VERB DET ADP PRON VERB ADP PRON VERB VERB DET
#
# You = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# I = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# knew = VERB VBD -> verb, past tense
# this = DET DT -> determiner
# so = ADP IN -> conjunction, subordinating or preposition
# I = PRON PRP -> pronoun, personal
# guess = VERB VBP -> verb, non-3rd person singular present
# that = ADP IN -> conjunction, subordinating or preposition
# we = PRON PRP -> pronoun, personal
# could = VERB MD -> verb, modal auxiliary
# do = VERB VB -> verb, base form
# this = DET DT -> determiner
# ------------------------------
# Quit denyin' it
# VERB VERB PUNCT PRON
#
# Quit = VERB VB -> verb, base form
# denyin = VERB VB -> verb, base form
# ' = PUNCT '' -> closing quotation mark
# it = PRON PRP -> pronoun, personal
# ------------------------------
# I ain't sure but I'll tell you what I do know
# PRON VERB ADV ADJ CCONJ PRON VERB VERB PRON NOUN PRON VERB VERB
#
# I = PRON PRP -> pronoun, personal
# ai = VERB VBP -> verb, non-3rd person singular present
# n't = ADV RB -> adverb
# sure = ADJ JJ -> adjective
# but = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# tell = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# what = NOUN WP -> wh-pronoun, personal
# I = PRON PRP -> pronoun, personal
# do = VERB VBP -> verb, non-3rd person singular present
# know = VERB VB -> verb, base form
# ------------------------------
# Plus you act like you need this
# CCONJ PRON VERB ADP PRON VERB DET
#
# Plus = CCONJ CC -> conjunction, coordinating
# you = PRON PRP -> pronoun, personal
# act = VERB VBP -> verb, non-3rd person singular present
# like = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# need = VERB VBP -> verb, non-3rd person singular present
# this = DET DT -> determiner
# ------------------------------
# Yo Shock this is pumpin' man, this sounds like somethin' I'd do!
# PROPN NOUN DET VERB ADJ PUNCT NOUN PUNCT DET VERB ADP NOUN PRON VERB VERB PUNCT
#
# Yo = PROPN NNP -> noun, proper singular
# Shock = NOUN NN -> noun, singular or mass
# this = DET DT -> determiner
# is = VERB VBZ -> verb, 3rd person singular present
# pumpin = ADJ JJ -> adjective
# ' = PUNCT '' -> closing quotation mark
# man = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# this = DET DT -> determiner
# sounds = VERB VBZ -> verb, 3rd person singular present
# like = ADP IN -> conjunction, subordinating or preposition
# somethin' = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'd = VERB MD -> verb, modal auxiliary
# do = VERB VB -> verb, base form
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# No, no Hump, come on man, no, no
# INTJ PUNCT INTJ NOUN PUNCT VERB ADP NOUN PUNCT INTJ PUNCT INTJ
#
# No = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# no = INTJ UH -> interjection
# Hump = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# come = VERB VB -> verb, base form
# on = ADP IN -> conjunction, subordinating or preposition
# man = NOUN NN -> noun, singular or mass
# , = PUNCT , -> punctuation mark, comma
# no = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# no = INTJ UH -> interjection
# ------------------------------
# People treat you coldly
# NOUN VERB PRON ADV
#
# People = NOUN NNS -> noun, plural
# treat = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# coldly = ADV RB -> adverb
# ------------------------------
# Hold my nose! Uh-huh
# VERB ADJ NOUN PUNCT INTJ PUNCT INTJ
#
# Hold = VERB VB -> verb, base form
# my = ADJ PRP$ -> pronoun, possessive
# nose = NOUN NN -> noun, singular or mass
# ! = PUNCT . -> punctuation mark, sentence closer
# Uh = INTJ UH -> interjection
# - = PUNCT HYPH -> punctuation mark, hyphen
# huh = INTJ UH -> interjection
# ------------------------------
# Awright, heh heh
# INTJ PUNCT INTJ INTJ
#
# Awright = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# heh = INTJ UH -> interjection
# heh = INTJ UH -> interjection
# ------------------------------
# I'll love you back
# PRON VERB VERB PRON ADV
#
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# Yeah, ladies?
# INTJ PUNCT NOUN PUNCT
#
# Yeah = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# ladies = NOUN NNS -> noun, plural
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# We chocolate cross-over
# PRON VERB NOUN PUNCT PART
#
# We = PRON PRP -> pronoun, personal
# chocolate = VERB VBP -> verb, non-3rd person singular present
# cross = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# over = PART RP -> adverb, particle
# ------------------------------
# I'll kiss you back, I'll kiss you back
# PRON VERB VERB PRON ADV PUNCT PRON VERB VERB PRON PART
#
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# We-we chocolate cross-over
# PRON PUNCT PRON VERB NOUN PUNCT PART
#
# We = PRON PRP -> pronoun, personal
# - = PUNCT : -> punctuation mark, colon or ellipsis
# we = PRON PRP -> pronoun, personal
# chocolate = VERB VBP -> verb, non-3rd person singular present
# cross = NOUN NN -> noun, singular or mass
# - = PUNCT HYPH -> punctuation mark, hyphen
# over = PART RP -> adverb, particle
# ------------------------------
# Mmmm-<kiss>
# NOUN X
#
# Mmmm-<kiss = NOUN NNS -> noun, plural
# > = X XX -> unknown
# ------------------------------
# Now it's about time that I cleared this
# ADV PRON VERB ADP NOUN ADJ PRON VERB DET
#
# Now = ADV RB -> adverb
# it = PRON PRP -> pronoun, personal
# 's = VERB VBZ -> verb, 3rd person singular present
# about = ADP IN -> conjunction, subordinating or preposition
# time = NOUN NN -> noun, singular or mass
# that = ADJ WDT -> wh-determiner
# I = PRON PRP -> pronoun, personal
# cleared = VERB VBD -> verb, past tense
# this = DET DT -> determiner
# ------------------------------
# But if you love me then I'll love you back
# CCONJ ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# But = CCONJ CC -> conjunction, coordinating
# if = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# love = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# then = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# love = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# And I guess you wanna know if I'm gonna be around
# CCONJ PRON VERB PRON VERB VERB ADP PRON VERB VERB PART VERB ADP
#
# And = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# guess = VERB VBP -> verb, non-3rd person singular present
# you = PRON PRP -> pronoun, personal
# wanna = VERB VBP -> verb, non-3rd person singular present
# know = VERB VB -> verb, base form
# if = ADP IN -> conjunction, subordinating or preposition
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# gon = VERB VBG -> verb, gerund or present participle
# na = PART TO -> infinitival to
# be = VERB VB -> verb, base form
# around = ADP IN -> conjunction, subordinating or preposition
# ------------------------------
# I hear ya, I hear ya Hump!
# PRON VERB PRON PUNCT PRON VERB PRON VERB PUNCT
#
# I = PRON PRP -> pronoun, personal
# hear = VERB VBP -> verb, non-3rd person singular present
# ya = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# I = PRON PRP -> pronoun, personal
# hear = VERB VBP -> verb, non-3rd person singular present
# ya = PRON PRP -> pronoun, personal
# Hump = VERB VB -> verb, base form
# ! = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Will me and you forever
# VERB PRON CCONJ PRON ADV
#
# Will = VERB MD -> verb, modal auxiliary
# me = PRON PRP -> pronoun, personal
# and = CCONJ CC -> conjunction, coordinating
# you = PRON PRP -> pronoun, personal
# forever = ADV RB -> adverb
# ------------------------------
# Freak me girl and I'll freak you back
# VERB PRON NOUN CCONJ PRON VERB VERB PRON PART
#
# Freak = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# girl = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# freak = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# Shimmy shimmy cocoa pop
# VERB VERB NOUN NOUN
#
# Shimmy = VERB VB -> verb, base form
# shimmy = VERB VB -> verb, base form
# cocoa = NOUN NN -> noun, singular or mass
# pop = NOUN NN -> noun, singular or mass
# ------------------------------
# Real cute is what you say to me
# ADJ ADJ VERB NOUN PRON VERB ADP PRON
#
# Real = ADJ JJ -> adjective
# cute = ADJ JJ -> adjective
# is = VERB VBZ -> verb, 3rd person singular present
# what = NOUN WP -> wh-pronoun, personal
# you = PRON PRP -> pronoun, personal
# say = VERB VBP -> verb, non-3rd person singular present
# to = ADP IN -> conjunction, subordinating or preposition
# me = PRON PRP -> pronoun, personal
# ------------------------------
# 'Cept I'd do it like this:
# PUNCT INTJ PRON VERB VERB PRON ADP DET PUNCT
#
# ' = PUNCT `` -> opening quotation mark
# Cept = INTJ UH -> interjection
# I = PRON PRP -> pronoun, personal
# 'd = VERB MD -> verb, modal auxiliary
# do = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# like = ADP IN -> conjunction, subordinating or preposition
# this = DET DT -> determiner
# : = PUNCT : -> punctuation mark, colon or ellipsis
# ------------------------------
# See me See me cocoa might go pop go pop
# VERB PRON VERB PRON NOUN VERB VERB VERB NOUN NOUN
#
# See = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# See = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# cocoa = NOUN NN -> noun, singular or mass
# might = VERB MD -> verb, modal auxiliary
# go = VERB VB -> verb, base form
# pop = VERB VB -> verb, base form
# go = NOUN NN -> noun, singular or mass
# pop = NOUN NN -> noun, singular or mass
# ------------------------------
# If you kiss me girl I'll kiss you back
# ADP PRON VERB PRON NOUN PRON VERB VERB PRON PART
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# kiss = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# girl = NOUN NN -> noun, singular or mass
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# kiss = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# back = PART RP -> adverb, particle
# ------------------------------
# Let's just keep it cool, you know what I'm sayin'?
# VERB PRON ADV VERB PRON ADJ PUNCT PRON VERB NOUN PRON VERB VERB PUNCT PUNCT
#
# Let = VERB VB -> verb, base form
# 's = PRON PRP -> pronoun, personal
# just = ADV RB -> adverb
# keep = VERB VB -> verb, base form
# it = PRON PRP -> pronoun, personal
# cool = ADJ JJ -> adjective
# , = PUNCT , -> punctuation mark, comma
# you = PRON PRP -> pronoun, personal
# know = VERB VBP -> verb, non-3rd person singular present
# what = NOUN WP -> wh-pronoun, personal
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# sayin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# If you touch me here I'll touch you there
# ADP PRON VERB PRON ADV PRON VERB VERB PRON ADV
#
# If = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# touch = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# here = ADV RB -> adverb
# I = PRON PRP -> pronoun, personal
# 'll = VERB MD -> verb, modal auxiliary
# touch = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# there = ADV RB -> adverb
# ------------------------------
# When you say I get the most out of this it kind of bothers me
# ADV PRON VERB PRON VERB DET ADJ ADP ADP DET PRON ADV ADV VERB PRON
#
# When = ADV WRB -> wh-adverb
# you = PRON PRP -> pronoun, personal
# say = VERB VBP -> verb, non-3rd person singular present
# I = PRON PRP -> pronoun, personal
# get = VERB VBP -> verb, non-3rd person singular present
# the = DET DT -> determiner
# most = ADJ JJS -> adjective, superlative
# out = ADP IN -> conjunction, subordinating or preposition
# of = ADP IN -> conjunction, subordinating or preposition
# this = DET DT -> determiner
# it = PRON PRP -> pronoun, personal
# kind = ADV RB -> adverb
# of = ADV RB -> adverb
# bothers = VERB VBZ -> verb, 3rd person singular present
# me = PRON PRP -> pronoun, personal
# ------------------------------
# We never want to disrespect you
# PRON ADV VERB PART VERB PRON
#
# We = PRON PRP -> pronoun, personal
# never = ADV RB -> adverb
# want = VERB VBP -> verb, non-3rd person singular present
# to = PART TO -> infinitival to
# disrespect = VERB VB -> verb, base form
# you = PRON PRP -> pronoun, personal
# ------------------------------
# What, what man? I ain't...
# NOUN PUNCT NOUN NOUN PUNCT PRON VERB ADV PUNCT
#
# What = NOUN WP -> wh-pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# what = NOUN WP -> wh-pronoun, personal
# man = NOUN NN -> noun, singular or mass
# ? = PUNCT . -> punctuation mark, sentence closer
# I = PRON PRP -> pronoun, personal
# ai = VERB VBP -> verb, non-3rd person singular present
# n't = ADV RB -> adverb
# ... = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Yeah.
# INTJ PUNCT
#
# Yeah = INTJ UH -> interjection
# . = PUNCT . -> punctuation mark, sentence closer
# ------------------------------

# %% [markdown]
# An interesting thing is that the POS tagger properly recognizes abbreviations such as "'ll'".
#
# Another important feature we can notice is when we analyze the following line: "Yeah, we chocolate cross-over". Here the word "chocolate" is used as a verb (even though chocolate is clearly not defined as a verb in the dictionary) and the POS tagger is able to recognize that. This is quite important because, in songs, those situations happen very often.
#
# Let's now consider a very long line and its analysis from above:
# ```
# Jus't havin' fun with it, man, know what I'm sayin'?
# NOUN VERB NOUN ADP PRON PUNCT INTJ PUNCT VERB NOUN PRON VERB VERB PUNCT PUNCT
#
# Jus't = NOUN NNS -> noun, plural
# havin' = VERB VBG -> verb, gerund or present participle
# fun = NOUN NN -> noun, singular or mass
# with = ADP IN -> conjunction, subordinating or preposition
# it = PRON PRP -> pronoun, personal
# , = PUNCT , -> punctuation mark, comma
# man = INTJ UH -> interjection
# , = PUNCT , -> punctuation mark, comma
# know = VERB VB -> verb, base form
# what = NOUN WP -> wh-pronoun, personal
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# sayin = VERB VBG -> verb, gerund or present participle
# ' = PUNCT '' -> closing quotation mark
# ? = PUNCT . -> punctuation mark, sentence closer
# ```
#
# For sure a very interesting thing we can notice are those two lines: `havin' = VERB VBG -> verb, gerund or present participle` and `sayin = VERB VBG -> verb, gerund or present participle` (the reason is obvious).
#
# One thing which is very impressive from the above analysis in when "man" is recognized to be an interjection. An interjection is a part of speech that shows the emotion or feeling of the author. These words or phrases can stand alone or be placed before or after a sentence. Many times an interjection is followed by a punctuation mark, often an exclamation point ([reference](http://examples.yourdictionary.com/examples-of-interjections.html)). This description perfectly fits with the usage of the word "man" in this context. However this one was not trivial to detect. This POS tagger feature is quite impressive and it is certainly very useful because songs tends to use those things quite often.
#
# By looking at the rest, everything seems to be fine.

# %% [markdown]
# ## Still good with vulgar song?
#
# **DISCLAIMER**: we did not want to seem impolite. We are discussing a vulgar song just because we want to see if our POS tagger performs good also in those situation. Vulgar songs are in fact quite common, especially in rap.
#
# For our purpose we analyzed "The Ballad Of Chasey Lain", from Bloodhound Gang.
#
# This song is not contained in MoodyLyrics so we need to download the lyrics.

# %%
import lyricwikia
lyrics = lyricwikia.get_lyrics('Bloodhound Gang', 'The Ballad Of Chasey Lain')

# %%
print(lyrics)
# Out:
# Dear Chasey Lain
# I wrote to explain
# I'm your biggest fan
# I just wanted to ask
# Could I eat your ass?
# Write back as soon as you can
#
# You've had a lotta dick
# Had a lotta dick
# I've had a lotta time
# Had a lotta time
# You've had a lotta dick Chasey
# But you ain't had mine
#
# Dear Chasey Lain
# I wrote to complain
# Ya never wrote me back
# How could I ever eat
# Your ass when ya treat
# Your biggest fan like that?
#
# You've had a lotta dick
# Had a lotta dick
# I've had a lotta time
# Had a lotta time
# You've had a lotta dick Chasey
# But you ain't had mine
#
# Dear Chasey Lain
# I wrote to constrain
# This letter is my last
# As your biggest fan
# I must demand
# You let me eat your ass
#
# You've had a lotta dick
# Had a lotta dick
# I've had a lotta time
# Had a lotta time
# You've had a lotta dick Chasey
# But you ain't had mine
#
# P. S
# Mom and Dad this is Chasey
# Chasey this is my mom and dad
# Now show 'em them titties
# Now show 'em them titties
# P. S
# Mom and Dad this is Chasey
# Chasey this is my mom and dad
# Now show 'em them titties
# Now show 'em them titties
#
# Would ya fuck me for blow?

# %% [markdown]
# Let's go straight to the point and analyze all the lyric after having dropped duplicates.

# %%
parts = lyrics.split('\n\n')
print('We had {} parts'.format(len(parts)))
parts = list(set(parts))
print('Now we have {} parts'.format(len(parts)))
# Out:
# We had 8 parts
# Now we have 6 parts

# %%
lyrics = nlp(lyrics)
lines = get_lines()

# %%
lines = list(set(lines))
# Also drop empty lines
lines = [line for line in lines if len(line) > 0]

# %%
for line in lines:
    describe_line(line)
    print('-'*30)
# Out:
# Had a lotta dick
# VERB DET NOUN NOUN
#
# Had = VERB VBD -> verb, past tense
# a = DET DT -> determiner
# lotta = NOUN NN -> noun, singular or mass
# dick = NOUN NN -> noun, singular or mass
# ------------------------------
# You've had a lotta dick Chasey
# PRON VERB VERB DET NOUN NOUN PROPN
#
# You = PRON PRP -> pronoun, personal
# 've = VERB VB -> verb, base form
# had = VERB VBN -> verb, past participle
# a = DET DT -> determiner
# lotta = NOUN NN -> noun, singular or mass
# dick = NOUN NN -> noun, singular or mass
# Chasey = PROPN NNP -> noun, proper singular
# ------------------------------
# I just wanted to ask
# PRON ADV VERB PART VERB
#
# I = PRON PRP -> pronoun, personal
# just = ADV RB -> adverb
# wanted = VERB VBD -> verb, past tense
# to = PART TO -> infinitival to
# ask = VERB VB -> verb, base form
# ------------------------------
# Could I eat your ass?
# VERB PRON VERB ADJ NOUN PUNCT
#
# Could = VERB MD -> verb, modal auxiliary
# I = PRON PRP -> pronoun, personal
# eat = VERB VB -> verb, base form
# your = ADJ PRP$ -> pronoun, possessive
# ass = NOUN NN -> noun, singular or mass
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Dear Chasey Lain
# PROPN PROPN PROPN
#
# Dear = PROPN NNP -> noun, proper singular
# Chasey = PROPN NNP -> noun, proper singular
# Lain = PROPN NNP -> noun, proper singular
# ------------------------------
# This letter is my last
# DET NOUN VERB ADJ ADJ
#
# This = DET DT -> determiner
# letter = NOUN NN -> noun, singular or mass
# is = VERB VBZ -> verb, 3rd person singular present
# my = ADJ PRP$ -> pronoun, possessive
# last = ADJ JJ -> adjective
# ------------------------------
# You let me eat your ass
# PRON VERB PRON VERB ADJ NOUN
#
# You = PRON PRP -> pronoun, personal
# let = VERB VBP -> verb, non-3rd person singular present
# me = PRON PRP -> pronoun, personal
# eat = VERB VB -> verb, base form
# your = ADJ PRP$ -> pronoun, possessive
# ass = NOUN NN -> noun, singular or mass
# ------------------------------
# Write back as soon as you can
# VERB ADV ADV ADV ADP PRON VERB
#
# Write = VERB VB -> verb, base form
# back = ADV RB -> adverb
# as = ADV RB -> adverb
# soon = ADV RB -> adverb
# as = ADP IN -> conjunction, subordinating or preposition
# you = PRON PRP -> pronoun, personal
# can = VERB MD -> verb, modal auxiliary
# ------------------------------
# I wrote to complain
# PRON VERB PART VERB
#
# I = PRON PRP -> pronoun, personal
# wrote = VERB VBD -> verb, past tense
# to = PART TO -> infinitival to
# complain = VERB VB -> verb, base form
# ------------------------------
# Your ass when ya treat
# ADJ NOUN ADV PRON VERB
#
# Your = ADJ PRP$ -> pronoun, possessive
# ass = NOUN NN -> noun, singular or mass
# when = ADV WRB -> wh-adverb
# ya = PRON PRP -> pronoun, personal
# treat = VERB VBP -> verb, non-3rd person singular present
# ------------------------------
# Chasey this is my mom and dad
# PROPN DET VERB ADJ NOUN CCONJ NOUN
#
# Chasey = PROPN NNP -> noun, proper singular
# this = DET DT -> determiner
# is = VERB VBZ -> verb, 3rd person singular present
# my = ADJ PRP$ -> pronoun, possessive
# mom = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# dad = NOUN NN -> noun, singular or mass
# ------------------------------
# Would ya fuck me for blow?
# VERB PRON VERB PRON ADP NOUN PUNCT
#
# Would = VERB MD -> verb, modal auxiliary
# ya = PRON PRP -> pronoun, personal
# fuck = VERB VB -> verb, base form
# me = PRON PRP -> pronoun, personal
# for = ADP IN -> conjunction, subordinating or preposition
# blow = NOUN NN -> noun, singular or mass
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# But you ain't had mine
# CCONJ PRON VERB ADV VERB PRON
#
# But = CCONJ CC -> conjunction, coordinating
# you = PRON PRP -> pronoun, personal
# ai = VERB VBP -> verb, non-3rd person singular present
# n't = ADV RB -> adverb
# had = VERB VBD -> verb, past tense
# mine = PRON PRP -> pronoun, personal
# ------------------------------
# How could I ever eat
# ADV VERB PRON ADV VERB
#
# How = ADV WRB -> wh-adverb
# could = VERB MD -> verb, modal auxiliary
# I = PRON PRP -> pronoun, personal
# ever = ADV RB -> adverb
# eat = VERB VB -> verb, base form
# ------------------------------
# P. S
# PROPN PROPN
#
# P. = PROPN NNP -> noun, proper singular
# S = PROPN NNP -> noun, proper singular
# ------------------------------
# As your biggest fan
# ADP ADJ ADJ NOUN
#
# As = ADP IN -> conjunction, subordinating or preposition
# your = ADJ PRP$ -> pronoun, possessive
# biggest = ADJ JJS -> adjective, superlative
# fan = NOUN NN -> noun, singular or mass
# ------------------------------
# I'm your biggest fan
# PRON VERB ADJ ADJ NOUN
#
# I = PRON PRP -> pronoun, personal
# 'm = VERB VBP -> verb, non-3rd person singular present
# your = ADJ PRP$ -> pronoun, possessive
# biggest = ADJ JJS -> adjective, superlative
# fan = NOUN NN -> noun, singular or mass
# ------------------------------
# Mom and Dad this is Chasey
# NOUN CCONJ PROPN DET VERB PROPN
#
# Mom = NOUN NN -> noun, singular or mass
# and = CCONJ CC -> conjunction, coordinating
# Dad = PROPN NNP -> noun, proper singular
# this = DET DT -> determiner
# is = VERB VBZ -> verb, 3rd person singular present
# Chasey = PROPN NNP -> noun, proper singular
# ------------------------------
# I've had a lotta time
# PRON VERB VERB DET NOUN NOUN
#
# I = PRON PRP -> pronoun, personal
# 've = VERB VB -> verb, base form
# had = VERB VBN -> verb, past participle
# a = DET DT -> determiner
# lotta = NOUN NN -> noun, singular or mass
# time = NOUN NN -> noun, singular or mass
# ------------------------------
# I must demand
# PRON VERB VERB
#
# I = PRON PRP -> pronoun, personal
# must = VERB MD -> verb, modal auxiliary
# demand = VERB VB -> verb, base form
# ------------------------------
# Now show 'em them titties
# ADV VERB PRON PRON NOUN
#
# Now = ADV RB -> adverb
# show = VERB VB -> verb, base form
# 'em = PRON PRP -> pronoun, personal
# them = PRON PRP -> pronoun, personal
# titties = NOUN NNS -> noun, plural
# ------------------------------
# I wrote to explain
# PRON VERB PART VERB
#
# I = PRON PRP -> pronoun, personal
# wrote = VERB VBD -> verb, past tense
# to = PART TO -> infinitival to
# explain = VERB VB -> verb, base form
# ------------------------------
# Ya never wrote me back
# INTJ ADV VERB PRON ADV
#
# Ya = INTJ UH -> interjection
# never = ADV RB -> adverb
# wrote = VERB VBD -> verb, past tense
# me = PRON PRP -> pronoun, personal
# back = ADV RB -> adverb
# ------------------------------
# You've had a lotta dick
# PRON VERB VERB DET NOUN NOUN
#
# You = PRON PRP -> pronoun, personal
# 've = VERB VB -> verb, base form
# had = VERB VBN -> verb, past participle
# a = DET DT -> determiner
# lotta = NOUN NN -> noun, singular or mass
# dick = NOUN NN -> noun, singular or mass
# ------------------------------
# Your biggest fan like that?
# ADJ ADJ NOUN ADP DET PUNCT
#
# Your = ADJ PRP$ -> pronoun, possessive
# biggest = ADJ JJS -> adjective, superlative
# fan = NOUN NN -> noun, singular or mass
# like = ADP IN -> conjunction, subordinating or preposition
# that = DET DT -> determiner
# ? = PUNCT . -> punctuation mark, sentence closer
# ------------------------------
# Had a lotta time
# VERB DET NOUN NOUN
#
# Had = VERB VBD -> verb, past tense
# a = DET DT -> determiner
# lotta = NOUN NN -> noun, singular or mass
# time = NOUN NN -> noun, singular or mass
# ------------------------------
# I wrote to constrain
# PRON VERB PART VERB
#
# I = PRON PRP -> pronoun, personal
# wrote = VERB VBD -> verb, past tense
# to = PART TO -> infinitival to
# constrain = VERB VB -> verb, base form
# ------------------------------

# %% [markdown]
# We will not go too much into the details of this analysis. What we will just say is that, again, we can not notice any problem in the words tagging.

# %% [markdown]
# # Conclusion
#
# The POS tagger embedded in spaCy's model language we are using is quite impressive. We did not find a specific case in which it performed really bad. For sure it is good for our purpose.
